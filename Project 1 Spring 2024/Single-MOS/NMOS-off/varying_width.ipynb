# %%
import subprocess
import os

netlist_template = """
*CONDUCTION NMOS W1

.INCLUDE ../../model/32nm_HP.pm
.OPTIONS GMIN=1e-020 ABSTOL=1e-18

*Definizione dei parametri
.PARAM Lmin=22n
.PARAM Wmin=22n
.PARAM Ldiff=44n

.TEMP 85

.PARAM N={n}

*Descrizione della cella
Mn drain gate source body nmos W={{Wmin*N}} L={{Lmin}} AS={{Wmin*N*Ldiff}} AD={{Wmin*N*Ldiff}} PS={{2*(Ldiff+Wmin*N)}} PD={{2*(Ldiff+Wmin*N)}}
Vd 	drain	alim		0
Vg 	gate	0		0
Vs 	source	0		0
Vb 	body	0		0
Vdd 	alim	0		0

*Definizione del tipo di analisi
.CONTROL
let voltage=-0.05
let Vddbasic=1.0

while voltage le Vddbasic
  let voltage = voltage + 0.05
  alter Vdd = voltage
  dc TEMP 85 86 10
  print abs(V(alim)) V(drain) V(gate) V(source) V(body) I(Vd) I(Vg) I(Vs) I(Vb)

end

.ENDC
.END

"""

n_values = [1, 2, 3, 4, 6, 8]

output_dir = "netlists_varying_width"

# make the directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

outs = []
for n in n_values:
    netlist_content = netlist_template.format(n=n)
    
    filename = f"{output_dir}/nmos_off_{n}.net"
    
    with open(filename, 'w') as file:
        file.write(netlist_content)
    
    p = subprocess.run(["ngspice", filename] , encoding='utf-8', 
stdout=subprocess.PIPE)
    windstr = p.stdout
    outs.append(windstr)
# Out:
# Note: Starting dynamic gmin stepping
# Trying gmin =   1.0000E-03 Note: One successful gmin step
# Trying gmin =   1.0000E-04 Note: One successful gmin step
# Trying gmin =   1.0000E-05 Warning: Further gmin increment
# Trying gmin =   5.6234E-05 Note: One successful gmin step
# Trying gmin =   2.3714E-05 Warning: Further gmin increment
# Trying gmin =   4.5316E-05 Note: One successful gmin step
# Trying gmin =   3.2781E-05 Warning: Further gmin increment
# Trying gmin =   4.1792E-05 Warning: Further gmin increment
# Trying gmin =   4.4408E-05 Note: One successful gmin step
# Trying gmin =   4.3080E-05 Note: One successful gmin step
# Trying gmin =   4.1792E-05 Warning: Further gmin increment
# Trying gmin =   4.2754E-05 Warning: Further gmin increment
# Trying gmin =   4.2999E-05 Note: One successful gmin step
# Trying gmin =   4.2958E-05 Warning: Further gmin increment
# Trying gmin =   4.2988E-05 Note: One successful gmin step
# Trying gmin =   4.2983E-05 Note: One successful gmin step
# Trying gmin =   4.2981E-05 Note: One successful gmin step
# Trying gmin =   4.2979E-05 Note: One successful gmin step
# Trying gmin =   4.2976E-05 Note: One successful gmin step
# Trying gmin =   4.2974E-05 Warning: Further gmin increment
# Trying gmin =   4.2976E-05 Warning: Last gmin step failed
# Warning: Dynamic gmin stepping failed
# Note: Starting true gmin stepping
# Trying gmin =   1.0000E-03 Note: One successful gmin step
# Trying gmin =   1.0000E-04 Note: One successful gmin step
# Trying gmin =   1.0000E-05 Note: One successful gmin step
# Trying gmin =   1.0000E-06 Note: One successful gmin step
# Trying gmin =   1.0000E-07 Note: One successful gmin step
# Trying gmin =   1.0000E-08 Note: One successful gmin step
# Trying gmin =   1.0000E-09 Note: One successful gmin step
# Trying gmin =   1.0000E-10 Note: One successful gmin step
# Trying gmin =   1.0000E-11 Note: One successful gmin step
# Trying gmin =   1.0000E-12 Note: One successful gmin step
# Trying gmin =   1.0000E-13 Note: One successful gmin step
# Trying gmin =   1.0000E-14 Note: One successful gmin step
# Trying gmin =   1.0000E-15 Warning: Further gmin increment
# Trying gmin =   5.6234E-15 Note: One successful gmin step
# Trying gmin =   2.3714E-15 Warning: Further gmin increment
# Trying gmin =   4.5316E-15 Note: One successful gmin step
# Trying gmin =   3.2781E-15 Note: One successful gmin step
# Trying gmin =   2.0169E-15 Warning: Further gmin increment
# Trying gmin =   2.9033E-15 Warning: Further gmin increment
# Trying gmin =   3.1801E-15 Warning: Further gmin increment
# Trying gmin =   3.2533E-15 Note: One successful gmin step
# Trying gmin =   3.2287E-15 Note: One successful gmin step
# Trying gmin =   3.1922E-15 Warning: Further gmin increment
# Trying gmin =   3.2196E-15 Warning: Further gmin increment
# Trying gmin =   3.2264E-15 Note: One successful gmin step
# Trying gmin =   3.2253E-15 Note: One successful gmin step
# Trying gmin =   3.2236E-15 Warning: Further gmin increment
# Trying gmin =   3.2249E-15 Note: One successful gmin step
# Trying gmin =   3.2247E-15 Note: One successful gmin step
# Trying gmin =   3.2243E-15 Warning: Further gmin increment
# Trying gmin =   3.2246E-15 Warning: Last gmin step failed
# Warning: True gmin stepping failed
# Note: Starting source stepping
# Supplies reduced to   0.0000% Note: One successful source step
# Supplies reduced to   0.1000% Note: One successful source step
# Supplies reduced to   0.2000% Note: One successful source step
# Supplies reduced to   0.3500% Note: One successful source step
# Supplies reduced to   0.5750% Note: One successful source step
# Supplies reduced to   0.9125% Note: One successful source step
# Supplies reduced to   1.4188% Note: One successful source step
# Supplies reduced to   2.1781% Note: One successful source step
# Supplies reduced to   3.3172% Note: One successful source step
# Supplies reduced to   5.0258% Note: One successful source step
# Supplies reduced to   7.5887% Note: One successful source step
# Supplies reduced to  11.4330% Note: One successful source step
# Supplies reduced to  17.1995% Note: One successful source step
# Supplies reduced to  25.8493% Note: One successful source step
# Supplies reduced to  38.8239% Note: One successful source step
# Supplies reduced to  58.2859% Note: One successful source step
# Supplies reduced to  87.4788% Supplies reduced to  58.2859% Note: One successful source step
# Supplies reduced to  59.2859% Note: One successful source step
# Supplies reduced to  60.7859% Note: One successful source step
# Supplies reduced to  63.0359% Note: One successful source step
# Supplies reduced to  66.4109% Note: One successful source step
# Supplies reduced to  71.4734% Note: One successful source step
# Supplies reduced to  79.0671% Note: One successful source step
# Supplies reduced to  90.4577% Note: One successful source step
# Supplies reduced to 100.0000% Supplies reduced to  90.4577% Note: One successful source step
# Supplies reduced to  91.4577% Note: One successful source step
# Supplies reduced to  92.9577% Note: One successful source step
# Supplies reduced to  95.2077% Note: One successful source step
# Supplies reduced to  98.5827% Note: One successful source step
# Supplies reduced to 100.0000% Supplies reduced to  98.5827% Note: One successful source step
# Supplies reduced to  99.0890% Supplies reduced to  98.5827% Note: One successful source step
# Supplies reduced to  98.6587% Note: One successful source step
# Supplies reduced to  98.7726% Note: One successful source step
# Supplies reduced to  98.9434% Note: One successful source step
# Supplies reduced to  99.1997% Note: One successful source step
# Supplies reduced to  99.5842% Supplies reduced to  99.1997% Note: One successful source step
# Supplies reduced to  99.2574% Note: One successful source step
# Supplies reduced to  99.3439% Note: One successful source step
# Supplies reduced to  99.4736% Note: One successful source step
# Supplies reduced to  99.6682% Note: One successful source step
# Supplies reduced to  99.9602% Note: One successful source step
# Supplies reduced to 100.0000% Supplies reduced to  99.9602% Note: One successful source step
# Supplies reduced to 100.0000% Supplies reduced to  99.9602% Note: One successful source step
# Supplies reduced to  99.9700% Note: One successful source step
# Supplies reduced to  99.9848% Note: One successful source step
# Supplies reduced to 100.0000% Supplies reduced to  99.9848% Note: One successful source step
# Supplies reduced to  99.9881% Note: One successful source step
# Supplies reduced to  99.9931% Supplies reduced to  99.9881% Note: One successful source step
# Supplies reduced to  99.9889% Note: One successful source step
# Supplies reduced to  99.9900% Note: One successful source step
# Supplies reduced to  99.9917% Supplies reduced to  99.9900% Note: One successful source step
# Supplies reduced to  99.9903% Note: One successful source step
# Supplies reduced to  99.9906% Supplies reduced to  99.9903% Note: One successful source step
# Supplies reduced to  99.9903% Note: One successful source step
# Supplies reduced to  99.9904% Note: One successful source step
# Supplies reduced to  99.9905% Note: One successful source step
# Supplies reduced to  99.9905% Supplies reduced to  99.9905% Note: One successful source step
# Supplies reduced to  99.9905% Note: One successful source step
# Supplies reduced to  99.9905% Note: One successful source step
# Supplies reduced to  99.9905% Note: One successful source step
# Warning: source stepping failed
# Note: Transient op started
# Note: Transient op finished successfully
# Note: No ".plot", ".print", or ".fourier" lines; no simulations run
# Note: No ".plot", ".print", or ".fourier" lines; no simulations run
# Note: No ".plot", ".print", or ".fourier" lines; no simulations run
# Note: No ".plot", ".print", or ".fourier" lines; no simulations run
# Note: No ".plot", ".print", or ".fourier" lines; no simulations run
# Note: No ".plot", ".print", or ".fourier" lines; no simulations run

# %%
lines = windstr.split('\n')
# make a matrix out of every 10-18 lines
matrix = []
for o in outs:
    lines = o.split('\n')
    curr = []
    # make a matrix out of every 10-18 lines
    for i in range(10, len(lines), 13):
        curr.append(lines[i:i+9])
    matrix.append(curr)

# %%
# make directory 
dir_name = "results"
os.makedirs(dir_name, exist_ok=True)

filename = f"{dir_name}/leakage_width_"
for i, n in enumerate(n_values):
    with open(filename + str(n) + ".csv", 'w') as file:
        file.write("Valim,Vd,Vg,Vs,Vb,Id,Ig,Is,Ib\n") 
        for j in range(len(matrix[i])):
            for k in range(9):
                value = matrix[i][j][k].split(' ')[-1]
                file.write(value + ",")
                
            file.write("\n")
